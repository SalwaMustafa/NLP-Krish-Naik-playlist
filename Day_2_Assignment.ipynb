# %% [markdown]
# <a href="https://colab.research.google.com/github/SalwaMustafa/NLP-Krish-Naik-playlist/blob/main/Day_2_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kagglehub pyspellchecker nltk

# %%
import kagglehub
import os
import pandas as pd

path = kagglehub.dataset_download("nicapotato/womens-ecommerce-clothing-reviews")
print("Dataset path:", path)

print(os.listdir(path))

file_path = os.path.join(path, "Womens Clothing E-Commerce Reviews.csv")
df = pd.read_csv(file_path)
# Out:
# Dataset path: /root/.cache/kagglehub/datasets/nicapotato/womens-ecommerce-clothing-reviews/versions/1
# ['Womens Clothing E-Commerce Reviews.csv']

# %%
df.head()
# Out:
#    Unnamed: 0  Clothing ID  Age                    Title  \
# 0           0          767   33                      NaN
# 1           1         1080   34                      NaN
# 2           2         1077   60  Some major design flaws
# 3           3         1049   50         My favorite buy!
# 4           4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0       Initmates        Intimate  Intimates
# ...

# %%
df.shape
# Out:
# (23486, 11)

# %%
df.describe()
# Out:
#          Unnamed: 0   Clothing ID           Age        Rating  \
# count  23486.000000  23486.000000  23486.000000  23486.000000
# mean   11742.500000    918.118709     43.198544      4.196032
# std     6779.968547    203.298980     12.279544      1.110031
# min        0.000000      0.000000     18.000000      1.000000
# 25%     5871.250000    861.000000     34.000000      4.000000
# 50%    11742.500000    936.000000     41.000000      5.000000
# 75%    17613.750000   1078.000000     52.000000      5.000000
# max    23485.000000   1205.000000     99.000000      5.000000
#
#        Recommended IND  Positive Feedback Count
# count     23486.000000             23486.000000
# mean          0.822362                 2.535936
# std           0.382216                 5.702202
# min           0.000000                 0.000000
# 25%           1.000000                 0.000000
# 50%           1.000000                 1.000000
# 75%           1.000000                 3.000000
# ...

# %%
df = df[['Review Text',	'Rating',	'Recommended IND',	'Positive Feedback Count']]

# %%
df.head()
# Out:
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count
# 0                        0
# 1                        4
# 2                        0
# 3                        0
# 4                        6

# %%
import nltk
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.corpus import stopwords, words
import re
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from spellchecker import SpellChecker
nltk.download('wordnet')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('words')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
df.isnull().sum()
# Out:
# Review Text                845
# Rating                       0
# Recommended IND              0
# Positive Feedback Count      0
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
stop_words = set(stopwords.words('english'))

# %%
negations_en = {
    "no", "not", "nor", "never", "neither", "none", "nobody", "nothing", "nowhere",
    "cannot", "can't", "dont", "don't", "doesnt", "doesn't", "didnt", "didn't",
    "isnt", "isn't", "wasnt", "wasn't", "werent", "weren't",
    "havent", "haven't", "hasnt", "hasn't", "hadnt", "hadn't",
    "won't", "wouldnt", "wouldn't", "shouldnt", "shouldn't", "mustnt", "mustn't",
    "aint","ain't", "aren't","couldn't",'didn','aren','hadn', 'hasn','haven', 'isn',
    'mightn', "mightn't",'mustn', 'needn',"needn't", 'can','didn', 'doesn','wouldn',
    'shouldn','isn', 'weren', 'wasn'
}

# %%
stop_words = stop_words - negations_en

# %%
spell = SpellChecker()
valid_words = set(w.lower() for w in words.words())

# %%
lemmatizer = WordNetLemmatizer()

def clean_text(text):
  text = re.sub('[^a-zA-Z]', ' ', text)
  text = text.lower()
  text = re.sub(r'(.)\1{2,}', r'\1\1', text)
  text = text.split()
  cleaned_words = []
  for word in text:
        if word not in stop_words and len(word) > 1:
            corrected = spell.correction(word)
            if corrected and corrected.lower() in valid_words:
                word = corrected.lower()
                word = lemmatizer.lemmatize(word)
                cleaned_words.append(word)
  return ' '.join(cleaned_words)

# %%
df['Review Text'] = df['Review Text'].apply(clean_text)

# %%
df.head()
# Out:
#                                          Review Text  Rating  Recommended IND  \
# 0        absolutely wonderful silky sexy comfortable       4                1
# 1  love dress so pretty find store glad be never ...       5                1
# 2  high dress really work initially ordered petit...       3                0
# 3  love love love fun flirty fabulous every time ...       5                1
# 4  shirt flattering due adjustable front tie perf...       5                1
#
#    Positive Feedback Count
# 0                        0
# 1                        4
# 2                        0
# 3                        0
# 4                        6

# %%
 cv = CountVectorizer()
 X_1 = cv.fit_transform(df['Review Text'])

# %%
sorted(cv.vocabulary_.items())[:50]
# Out:
# [('aalii', 0),
#  ('ab', 1),
#  ('abbey', 2),
#  ('abby', 3),
#  ('abdomen', 4),
#  ('abdominal', 5),
#  ('abhor', 6),
#  ('ability', 7),
#  ('abject', 8),
#  ('able', 9),
#  ('abnormal', 10),
#  ('abnormally', 11),
#  ('about', 12),
#  ('abroad', 13),
#  ('abruptly', 14),
#  ('absence', 15),
#  ('absolute', 16),
#  ('absolutely', 17),
#  ('absorbent', 18),
#  ('abstract', 19),
#  ('absurd', 20),
#  ('absurdly', 21),
#  ('abundance', 22),
#  ('abundant', 23),
#  ('abut', 24),
#  ('acacia', 25),
#  ('accent', 26),
#  ('accentuate', 27),
#  ('accept', 28),
#  ('acceptable', 29),
#  ('acceptably', 30),
#  ('accepted', 31),
#  ('access', 32),
#  ('accessory', 33),
#  ('accident', 34),
#  ('accidental', 35),
#  ('accidentally', 36),
#  ('accommodate', 37),
#  ('accommodating', 38),
#  ('accompany', 39),
#  ('accomplish', 40),
#  ('accomplishment', 41),
#  ('accord', 42),
#  ('accordance', 43),
#  ('according', 44),
#  ('accordingly', 45),
#  ('accordion', 46),
#  ('account', 47),
# ...

# %%
TFIDF = TfidfVectorizer()
X_2 = TFIDF.fit_transform(df['Review Text'])

# %%
sorted(TFIDF.vocabulary_.items())[:50]
# Out:
# [('aalii', 0),
#  ('ab', 1),
#  ('abbey', 2),
#  ('abby', 3),
#  ('abdomen', 4),
#  ('abdominal', 5),
#  ('abhor', 6),
#  ('ability', 7),
#  ('abject', 8),
#  ('able', 9),
#  ('abnormal', 10),
#  ('abnormally', 11),
#  ('about', 12),
#  ('abroad', 13),
#  ('abruptly', 14),
#  ('absence', 15),
#  ('absolute', 16),
#  ('absolutely', 17),
#  ('absorbent', 18),
#  ('abstract', 19),
#  ('absurd', 20),
#  ('absurdly', 21),
#  ('abundance', 22),
#  ('abundant', 23),
#  ('abut', 24),
#  ('acacia', 25),
#  ('accent', 26),
#  ('accentuate', 27),
#  ('accept', 28),
#  ('acceptable', 29),
#  ('acceptably', 30),
#  ('accepted', 31),
#  ('access', 32),
#  ('accessory', 33),
#  ('accident', 34),
#  ('accidental', 35),
#  ('accidentally', 36),
#  ('accommodate', 37),
#  ('accommodating', 38),
#  ('accompany', 39),
#  ('accomplish', 40),
#  ('accomplishment', 41),
#  ('accord', 42),
#  ('accordance', 43),
#  ('according', 44),
#  ('accordingly', 45),
#  ('accordion', 46),
#  ('account', 47),
# ...
